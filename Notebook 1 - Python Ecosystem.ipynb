# %% [markdown]
# # Intro to Python - Notebook 1

# %% [markdown]
# # The Python/PyData Ecosystem
#
# <img src="http://ww2.sinaimg.cn/large/5396ee05jw1etyjkwzuo3j20jn0estco.jpg" align="center
#
#
# - There's a whole collection of tooling and packages geared towards scientific computing
#
#
# - Collaboration and reproducability are key concepts
#
#     - Let's talk about Anaconda
#
#     - Let's talk about Jupyter
#
#
# - Why use Python?
#
#     - Python is general purpose
#
#     - Many versitile libraries and packages (NumPy, Pandas etc.)
#
#     - Python is glue

# %% [markdown]
# ## How do I know what version I'm running?

# %%
import sys
print(sys.version)

# %% [markdown]
# ## Numpy & Pandas are your bread and butter
#
# #### NumPy
# http://www.numpy.org
#
# NumPy is the fundamental package for scientific computing with Python. It contains among other things:
#
# *  a powerful N-dimensional array object
# *  sophisticated (broadcasting) functions
# *  tools for integrating C/C++ and Fortran code
# *  useful linear algebra, Fourier transform, and random number capabilities
#
# Besides its obvious scientific uses, NumPy can also be used as an efficient multi-dimensional container of generic data. Arbitrary data-types can be defined. This allows NumPy to seamlessly and speedily integrate with a wide variety of databases.
#
#
# #### Pandas
#
# Python has long been great for data munging and preparation, but less so for data analysis and modeling. Pandas helps fill this gap, enabling you to carry out your entire data analysis workflow in Python without having to switch to a more domain specific language like R.
#
# *  **Fast, in-memory**: Great solution for small-medium sized data
# *  **Excellent time series functionality**: Handles dates and times effortlessly and supports a host of windowing functions
# *  **Split-apply-combine**:  Complex aggregations can be accomplished in a single line of code, pivoting too
# *  **Vectorizec computation**:  Via map(), apply(), and applymap()
# *  **Imputation is a breeze**:  Several convenient strategies for handling missing values

# %% [markdown]
# ### Let's quickly look at some basic examples of what they can help with

# %%
#import packages

import numpy as np #np is the conventional way to import numpy
import pandas as pd #pd is the conventional way to import pandas
from numpy.random import randn
from pandas import DataFrame

# %%
#create some dummy data and print its shape and top rows

df = DataFrame(randn(1000, 2), columns=list('ab'))
print(df.shape)
df.head()
# Out:
# (1000, 2)
#           a         b
# 0  1.441870  1.500636
# 1  1.544048 -0.021347
# 2  0.947956  2.875129
# 3 -0.604018 -1.060344
# 4 -0.737191  0.424619

# %%
#pandas has some built in capabilities that make it easy to run descriptive stats

df.describe()
# Out:
#                  a            b
# count  1000.000000  1000.000000
# mean     -0.013415     0.033438
# std       0.992031     1.004565
# min      -3.730419    -3.198343
# 25%      -0.662563    -0.641221
# 50%       0.015950     0.013627
# 75%       0.667076     0.662412
# max       3.265988     3.506821

# %% [markdown]
# Interpretation & use???

# %%
#add another column of random data

df['c'] = np.random.normal(0,4,1000)

# %% [markdown]
# What do we know about normally distributed data?
#
# What if we want to get rid of 'outliers'?

# %%
#df.head(10)

# %%
#create a new object that doesn't contain observations outside of 3 standard deviations

df2 = df[np.abs(df.c-df.c.mean())<=(3*df.c.std())] 
print(df2.shape)
# Out:
# (998, 3)

# %% [markdown]
# How much did we change our data?

# %% [markdown]
# You can also do basic filtering using different conditions

# %%
#create a new object containing observations where 'a' > 'b'
df3 = df.query('a > b') #df3 = df[df.a > df.b]
print(df3.shape)
# Out:
# (481, 3)

# %% [markdown]
# #### What if you have some real data?

# %% [markdown]
# Always start by making sure you're referencing the correct directory

# %%
#show present working directory
# %pwd
# Out:
# 'C:\\Users\\Tyler\\Desktop\\Katie\\Intro to Python (Spring A 2019)'

# %%
#set your working directory
#cd C:\\Users\\Owner\\Documents\\MS in BIA\\Teaching\\2018 Fall\\Intro to Python\\Notebooks & Data

# %% [markdown]
# For those familiar with R, importing and printing a Pandas array is like an R Dataframe

# %%
#import data
video = pd.read_csv("Video_Store.csv")
print("The below is the output of my data set")
print(" ")
print(video)
# Out:
# The below is the output of my data set
#
#     Cust ID Gender  Income  Age  Rentals  Avg Per Visit Incidentals   Genre
# 0         1      M   45000   25       32            2.5         Yes  Action
# 1         2      F   54000   33       12            3.4          No   Drama
# 2         3      F   32000   20       42            1.6          No  Comedy
# 3         4      F   59000   70       16            4.2         Yes   Drama
# 4         5      M   37000   35       25            3.2         Yes  Action
# 5         6      M   18000   20       29            1.7          No  Action
# 6         7      F   29000   45       19            3.8          No   Drama
# 7         8      M   74000   25       31            2.4         Yes  Action
# 8         9      M   38000   21       18            2.1          No  Comedy
# 9        10      F   65000   40       21            3.3          No   Drama
# 10       11      F   41000   22       48            2.3         Yes   Drama
# ...

# %% [markdown]
# ##### Printing entire datasets is helpful for exploring the data, but never submit code without commenting it out

# %%
#print a list of the column names
video.columns
# Out:
# Index(['Cust ID', 'Gender', 'Income', 'Age', 'Rentals', 'Avg Per Visit',
#        'Incidentals', 'Genre'],
#       dtype='object')

# %%
#print a list of the data types
video.dtypes
# Out:
# Cust ID            int64
# Gender            object
# Income             int64
# Age                int64
# Rentals            int64
# Avg Per Visit    float64
# Incidentals       object
# Genre             object
# dtype: object

# %%
#change a data type
video['Cust ID'] = video['Cust ID'].astype('object')

# %%
#check to make sure it worked appropriately
video.dtypes
# Out:
# Cust ID           object
# Gender            object
# Income             int64
# Age                int64
# Rentals            int64
# Avg Per Visit    float64
# Incidentals       object
# Genre             object
# dtype: object

# %% [markdown]
# ## What if you want to do some plotting?
# ### Matplotlib is one of the go-to plotting libraries

# %%
#import packages
#set output to show inline
#select plot style

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
# simple plotting
df = sns.load_dataset('iris')
df.plot(figsize=(15,5), title='Take that Nate Silver!')

# %% [markdown]
# ### Seaborn
#
# <img src="http://www.juno-books.com/i/seaborn245.jpg" width="20%" align="right">
#
# - Seaborn is a Python visualization library based on matplotlib
#
#
# - It provides a high-level interface for drawing attractive statistical graphics
#
#
# - It has some seriously powerful visualizations
#
#
# - Checkout the gallery: http://web.stanford.edu/~mwaskom/software/seaborn/examples/index.html

# %%
import seaborn as sns
x = np.random.normal(size=100)
sns.distplot(x);
# Out:
# C:\Users\Tyler\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(style="darkgrid")

mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

g = sns.jointplot(x="x", y="y", data=df, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")
